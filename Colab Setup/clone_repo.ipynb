# %% [markdown]
# # Steps
# 1. Set up a GitLab Personal Access token on https://gitlab.lrz.de/-/profile/personal_access_tokens with the name `colab-token` & the scope `write_repository`
# 2. Upload this notebook to your `Colab Notebooks` directory within your Google Drive
# 3. Open this notebook with Google Colab
# 4. Replace every occurrence of `your-access-token` with the value of the GitLab Personal Access token created in step 1
# 5. Replace `your_username` and `your@email.com` with your username and email for git
# 6. Run the notebook on Google Colab
# Notebook mostly taken from Roman Mayr

# %% [markdown]
# # Set Up Folders & Configure Git

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# !git config --global user.name "your_username"
# !git config --global user.email "your@email.com"

# %%
# !pwd

# %%
# %cd /content/drive/MyDrive/

# %%
# !mkdir nlp_ss24

# %% [markdown]
# # Clone multilingual lexical simplification repository

# %%
# %cd /content/drive/MyDrive/nlp_ss24

# %%
# !git clone https://colab-token:your-access-token@gitlab.lrz.de/practical-courses/nlp-lab-course-ss24/multilingual-lexical-simplification.git

# %%
# !pwd

# %%
# %cd /content/drive/MyDrive/nlp_ss24/multilingual-lexical-simplification/

# %%
# !git status

# %%
# !git checkout main
