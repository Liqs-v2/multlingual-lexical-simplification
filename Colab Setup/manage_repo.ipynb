# %% [markdown]
# # Instructions
# 1. Make sure that you have setup the repository in your Google Drive (e.g. by following the steps in `clone_repo.ipynb`)
# 2. Replace `your_username` and `your_username` with your username and email for git
# 3. Run the cells for connecting your Google Drive & configuring git
# 4. Run `git status` & `git fetch`
# 5. Run the cell for checking out your desired branch
# 6. If you made any changes to the Google Drive repository (e.g. by running or modifying one of the notebooks in Colab) and now you want to pull new changes:
#    1. Transfer any changes you want to keep to your local clone of the repository and commit them from there.
#    2. Revert changes to tracked files in the Google Drive repository by following the steps in the section "Reset and/or Clean".
# 7. Run `git pull`
# Notebook mostly taken from Roman Mayr

# %% [markdown]
# # Connect Drive & Configure Git

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# !git config --global user.name "your_username"
# !git config --global user.email "your_username"

# %%
# Move to repo directory
# %cd /content/drive/MyDrive/nlp_ss24/multilingual-lexical-simplification/

# %% [markdown]
# # Status

# %%
# !git status

# %% [markdown]
# # Fetch

# %%
# !git fetch

# %% [markdown]
# # Checkout

# %%
# Set the branch name to the desired branch
# !git checkout main

# %% [markdown]
# # Pull

# %%
# !git pull

# %% [markdown]
# # Diff

# %%
# !git diff
